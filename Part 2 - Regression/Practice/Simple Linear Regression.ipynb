# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Linear_Regression/Salary_Data.csv")

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, 1].values
print(X.shape)
# Out:
# (30, 1)

# %%
X = StandardScaler().fit_transform(X)
X.shape
# Out:
# (30, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((24, 1), (24,), (6, 1), (6,))

# %%
lr = LinearRegression()

lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)

#plot all data as red dots
plt.scatter(X_train, y_train, color='red')
#regression line : we want to compare the predicted training data with the real data(blue lines)
plt.plot(X_train, lr.predict(X_train), color="blue")
plt.title("Salary vs Experience (Training Set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
#we need to visualize the test part compared to linear regression line
plt.scatter(X_test, y_test, color="red")
plt.scatter(X_test, y_pred, color="green")
#we need to compare with the train linear regression line, we keep it!
plt.plot(X_train, lr.predict(X_train), color="blue")
plt.show()
